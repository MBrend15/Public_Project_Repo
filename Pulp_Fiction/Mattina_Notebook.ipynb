# %%
import pandas as pd
import numpy as np

# %%
#load full ratings df, then load fractional df for ease of use
full_ratings = pd.read_csv('./data/ratings.csv')
r_samp = full_ratings.sample(frac = .05)
r_samp_1 = full_ratings.sample(frac = .01)

# %%
#get an idea of the data in ratings df
r_samp.head()
# Out:
#           userId  movieId  rating   timestamp
# 21433726  139288    51255     2.0  1245779928
# 5483789    35545   135534     4.0  1492030357
# 10241600   66381     1276     3.5  1229440800
# 8433812    54939     3471     4.0  1299834194
# 13465667   87100   161956     2.5  1529861828

# %%
#load all the other relevant databases
tags = pd.read_csv('./data/tags.csv')
g_tags = pd.read_csv('./data/genome-tags.csv')
movies = pd.read_csv('./data/movies.csv')
g_scores = pd.read_csv('./data/genome-scores.csv')

# %%
#practice merging ratings and movie df to align movies with ratings
m_samp = pd.merge(r_samp_1,movies, on='movieId')
#print df shape to observe a proper merge and take a peek at the df
print(m_samp.shape)
print(r_samp_1.shape)
r_samp_1.head()
# Out:
# (250001, 6)
# (250001, 4)
#           userId  movieId  rating   timestamp
# 20673562  134427     1597     4.0   919874491
# 18023910  116760     1047     1.0   851118321
# 21690921  141005      387     3.0   998681226
# 10692043   69434     2571     1.0   955909829
# 5704018    36917     4226     4.0  1354571926

# %%
#take a peek at the data from the merged df, you can see movies and genres along with ratings
m_samp.sample(5)
# Out:
#         userId  movieId  rating   timestamp  \
# 65813   158108     1090     3.0  1001122463
# 19384    15459     1407     3.5  1087335311
# 131493   76604     2628     0.5  1171337355
# 69301   156397     1233     3.5  1124387378
# 186787   79381     7022     4.0  1372455365
#
#                                                    title  \
# 65813                                     Platoon (1986)
# 19384                                      Scream (1996)
# 131493  Star Wars: Episode I - The Phantom Menace (1999)
# 69301                       Boot, Das (Boat, The) (1981)
# 186787            Battle Royale (Batoru rowaiaru) (2000)
#
#                                 genres
# 65813                        Drama|War
# 19384   Comedy|Horror|Mystery|Thriller
# 131493         Action|Adventure|Sci-Fi
# 69301                 Action|Drama|War
# 186787    Action|Drama|Horror|Thriller

# %%
#take a peek at just the tags df you can see ratings assigned to each movie
tags.sample(5)
# Out:
#          userId  movieId           tag   timestamp
# 125760     6550    80574       revenge  1527134999
# 485618    51383    97921         drama  1492207158
# 434242    42657    91658          rape  1522872897
# 550336    62199     7894  Sergio Leone  1239047736
# 1017464  149526    33794         ninja  1158375843

# %%
#group this db by movie and see the max amount of tags assigned to a movie
#max = 6200
#mean = 25
#std = 108
gp_tags = tags.groupby('movieId')
#what happens when I remove the duplicates?
tags.groupby('movieId').get_group(260).tag.drop_duplicates().count()
# Out:
# 766

# %%
#there are up to 6180 tags for one movie, what movie is it
#Star Wars, a new Hope
movies.iloc[257]
# Out:
# movieId                                          260
# title      Star Wars: Episode IV - A New Hope (1977)
# genres                       Action|Adventure|Sci-Fi
# Name: 257, dtype: object

# %%
#A look at the tags df, you can see, it's just each tag along with a tag ID
#should de_duplicate tags
g_tags.sample(5)
# Out:
#      tagId          tag
# 917    918       silent
# 94      95        awful
# 770    771   passionate
# 33      34       africa
# 811    812  pretentious

# %%
#First look at genome scores df, will work off this df to build comprehensive tag df
g_scores.sample(5)
# Out:
#           movieId  tagId  relevance
# 5514453      5438    790    0.06275
# 3897976      3855    737    0.03500
# 100215         90    952    0.03625
# 8807552     31104    129    0.09775
# 11621191    79029    536    0.13225

# %%
g_scores.shape #gscores has a lot of rows, 15584448 to be exact
# Out:
# (15584448, 3)

# %%
#join genome scores and actual tags
g_score_m = pd.merge(g_scores,g_tags, on='tagId')
g_score_m.sample(10)
# Out:
#           movieId  tagId  relevance                  tag
# 14101486    56474   1021    0.01300     terminal illness
# 1278773     27735     93    0.00850              awesome
# 2184623      1933    159    0.07525               boxing
# 3044766      5881    221    0.52250               clones
# 8562011     70708    620    0.21375        mad scientist
# 3215839     84137    233    0.00500  comic book adaption
# 5071179       780    368    0.16425       existentialism
# 10643634     5968    771    0.13650           passionate
# 5241153      5439    380    0.03700              fascism
# 9043476     31123    655    0.06575     mission from god

# %%
#now group scores by movieId, and get the first group to work as a sample
#sort g score merge by movie id may relieve the weird error I am having later
g_score_m = g_score_m.sort_values(by = 'movieId')
g_score_m = g_score_m.reset_index(level = 0, drop = True)
gs_gp = g_score_m.groupby(g_score_m.movieId)
samp = gs_gp.get_group(1)
samp2 = gs_gp.get_group(2)
type(gs_gp)
# Out:
# pandas.core.groupby.groupby.DataFrameGroupBy

# %%
gs_gp.mean().mean()
# Out:
# tagId        564.500000
# relevance      0.116368
# dtype: float64

# %%
import sys
import datetime
import time

# Create 2 new columns in ratings dataframe: datetime object and year rating was written.
# This takes a VERY long time to run. If anyone can figure why the O(n) is so terrible, let me know.

def tag_tstamp2(row):
    
    time_set = set()
    
    #cnt = row.index[0]
    
    if row.user_tag:
        ttimes = gp_tags.get_group(row.movieId)\
            .timestamp[gp_tags.get_group(row.movieId).tag == row.tag] 
        for t in ttimes:
            time_set.add(t)
        
        time_set = np.array(time_set)
        
    else: 
        
        time_set = np.nan
        
    
    return time_set
        
        

#function to return the top 100 tags and add cols to the df for eventual operations to determine
#user tags and timestamps

#second improved and working verion of top g!
def top_g(x):
    
    try: 
        #first thing is to create the user tag, have to place in a try block because
        #some movies do not have user tags. So you are assigning a boolean series
        #based on whether users tagged movies with a scored tag
        y = x.assign(user_tag = x.tag.isin(gp_tags.get_group(x.movieId.iloc[0]).tag))
        
    except:
        #if you hit a key error, aka no tags, then simply assign a false boolean series
        y = x.assign(user_tag = [False]*len(x.index))
        
    y = y.assign(ut_tstamp = [np.nan]*len(x.index))
    
    y = y.sort_values(by = 'relevance', ascending = False).iloc[0:100]
    #y.user_tag = gp_tags.get_group(y.movieId.iloc[0]).tag.drop_duplicates().isin(y.tag)
    
    #tag_tstamp(y)
    
    return y
    
        

#operate on sample series


#s2 = top_g(gs_gp2.get_group(1))
#tag_tstamp(s2)
#s2.head(5)
#gp_tags.get_group(84).tag.head(5)
#gp_tags.get_group(56)
#gs_gp2 = gs_gp.apply(top_g)
#gs_gp2 = gs_gp2.reset_index(level = [0,1], drop = True)
#gs_gp2 = gs_gp2.groupby(gs_gp2.movieId)
#gs_gp2.head(1)

# %%
gs_gp3 = gs_gp2.groupby(gs_gp2.movieId)
s1 = gs_gp3.get_group(1)
s1.head(5)
# Out:
#    movieId  tagId  relevance                 tag  user_tag  ut_tstamp
# 0        1   1036    0.99925                toys      True        NaN
# 1        1    244    0.99875  computer animation      True        NaN
# 2        1    786    0.99575     pixar animation     False        NaN
# 3        1    589    0.98575     kids and family      True        NaN
# 4        1     64    0.98425           animation      True        NaN

# %%
s2 = gs_gp2.iloc[0:90000]
import time
gs_gp2.shape
# Out:
# (1381600, 6)

# %%
t1 = time.time()

gs_gp2.ut_tstamp = gs_gp2.apply(lambda x: tag_tstamp2(x),axis = 1)

#tag_tstamp(s1)

print(time.time() - t1)
# Out:
# 187.21835923194885
#      movieId  tagId  relevance                            tag  user_tag  \
# 400        5    901    0.96025                         sequel      True
# 401        5    451    0.95400                    good sequel     False
# 402        5    383    0.94825   father daughter relationship     False
# 403        5    902    0.94100                        sequels     False
# 404        5    808    0.91275                      pregnancy      True
# 405        5    650    0.90625                 midlife crisis      True
# 406        5    374    0.86875                         family      True
# 407        5    230    0.83925                         comedy     False
# 408        5    768    0.75900                     parenthood     False
# 409        5    388    0.75300                      feel-good     False
# 410        5    742    0.71925                       original     False
# 411        5    387    0.65475                feel good movie     False
# 412        5    900    0.64900                    sentimental     False
# 413        5    417    0.64550                          funny     False
# 414        5   1102    0.64475                        wedding      True
# 415        5   1035    0.63425                       touching     False
# 416        5    299    0.63150                        destiny     False
# 417        5    439    0.62825                   girlie movie     False
# 418        5    849    0.61225                         remake     False
# 419        5    524    0.61200                       hospital     False
# 420        5    807    0.61125                    predictable     False
# 421        5    279    0.60375                          cute!     False
# 422        5   1033    0.58725                      too short     False
# 423        5    464    0.58700                          great     False
# 424        5    195    0.58150                          chase     False
# 425        5    415    0.58075                      fun movie     False
# 426        5    445    0.55750                           good     False
# 427        5    922    0.54650                  single father     False
# 428        5    188    0.54475                    catastrophe     False
# 429        5    646    0.53675                         mentor     False
# 430        5    376    0.53500                   family drama     False
# 431        5    278    0.51200                           cute     False
# 432        5    497    0.48650                   heartwarming     False
# 433        5    264    0.44950                  crappy sequel     False
# 434        5   1071    0.44150                     very funny     False
# 435        5    313    0.44025                        divorce     False
# 436        5   1003    0.43475                          sweet     False
# 437        5    277    0.43025                  culture clash     False
# 438        5    777    0.42000                          pg-13     False
# 439        5    694    0.41575               natural disaster     False
# 440        5    926    0.41375                      slapstick     False
# 441        5    867    0.40500                        runaway     False
# 442        5   1116    0.40225                          women     False
# 443        5   1070    0.40150                      vengeance     False
# 444        5    490    0.39075                   happy ending     False
# 445        5    468    0.38000                   great ending     False
# 446        5    138    0.37950                    bittersweet     False
# 447        5    455    0.37400                          goofy     False
# 448        5    726    0.37375  nudity (full frontal - brief)     False
# 449        5    436    0.36800               ghosts/afterlife     False
#
#                     ut_tstamp
# 400              {1137102574}
# 401                       NaN
# 402                       NaN
# 403                       NaN
# 404  {1147409794, 1528513373}
# 405              {1528513373}
# 406  {1147409796, 1137102574}
# 407                       NaN
# 408                       NaN
# 409                       NaN
# 410                       NaN
# 411                       NaN
# 412                       NaN
# 413                       NaN
# 414  {1147449768, 1137102574}
# 415                       NaN
# 416                       NaN
# 417                       NaN
# 418                       NaN
# 419                       NaN
# 420                       NaN
# 421                       NaN
# 422                       NaN
# 423                       NaN
# 424                       NaN
# 425                       NaN
# 426                       NaN
# 427                       NaN
# 428                       NaN
# 429                       NaN
# 430                       NaN
# 431                       NaN
# 432                       NaN
# 433                       NaN
# 434                       NaN
# 435                       NaN
# 436                       NaN
# 437                       NaN
# 438                       NaN
# 439                       NaN
# 440                       NaN
# 441                       NaN
# 442                       NaN
# 443                       NaN
# 444                       NaN
# 445                       NaN
# 446                       NaN
# 447                       NaN
# 448                       NaN
# 449                       NaN

# %%
gs_gp2.to_csv('updated_tags.csv')

# %%
#will have to adjust tags accoridngly, still getting an index error
#gs_gp3 = gs_gp2.groupby(gs_gp2.movieId)
print(gs_gp3.ut_tstamp.count().mean(),gs_gp3.ut_tstamp.count().std())
# Out:
# 5.841488129704691 6.034446055506499

# %%
s2.dtypes

# %%
#function to create a new data frame, essentially by concatenating every group. Very, very slow
#but a useful snippet to have around. 

def c_cat_df(grp_df):
    
    tot = pd.DataFrame()
    
    for key in grp_df.groups:
        
        df = grp_df.get_group(key)
        tag_tstamp(df)
        tot = pd.concat([tot,df])
        
    return tot

tot = c_cat_df(gs_gp2)
        
tot.head(5)

# %%
#second improved and working verion of top g!
def top_g2(x):
    
    try: 
        #first thing is to create the user tag, have to place in a try block because
        #some movies do not have user tags. So you are assigning a boolean series
        #based on whether users tagged movies with a scored tag
        y = x.assign(user_tag = x.tag.isin(gp_tags.get_group(x.movieId.iloc[0]).tag))
        
    except:
        #if you hit a key error, aka no tags, then simply assign a false boolean series
        y = x.assign(user_tag = [False]*len(x.index))
        
    #y = y.assign(ut_tstamp = [np.nan]*len(x.index))
    
    y['ut_tstamp'] = y.apply(lambda x : tag_tstamp2(x),axis = 1)
    
    y = y.sort_values(by = 'relevance', ascending = False).iloc[0:25]
    
    return y

# %%
gs_gp2 = gs_gp.apply(top_g2)
gs_gp2 = gs_gp2.reset_index(level = [0,1], drop = True)
gs_gp2 = gs_gp2.groupby(gs_gp2.movieId)
gs_gp2.head(5)
# Out:
#         movieId  tagId  relevance  \
# 0             1   1036    0.99925
# 1             1    244    0.99875
# 2             1    786    0.99575
# 3             1    589    0.98575
# 4             1     64    0.98425
# 25            2     29    0.97600
# 26            2    204    0.95900
# 27            2    377    0.95175
# 28            2    588    0.95000
# 29            2    951    0.93200
# 50            3    901    0.97525
# 51            3    451    0.96250
# 52            3    902    0.93050
# 53            3    230    0.85300
# 54            3    742    0.75425
# 75            4   1116    0.97525
# 76            4    201    0.89900
# 77            4    313    0.82375
# 78            4    439    0.79000
# 79            4    864    0.76400
# 100           5    901    0.96025
# 101           5    451    0.95400
# 102           5    383    0.94825
# 103           5    902    0.94100
# 104           5    808    0.91275
# 125           6    268    0.97975
# 126           6    498    0.95700
# 127           6    105    0.94450
# 128           6    465    0.94250
# 129           6     19    0.93025
# ...         ...    ...        ...
# 345250   204704    374    0.88600
# 345251   204704    801    0.85725
# 345252   204704    742    0.84025
# 345253   204704    522    0.81925
# 345254   204704   1101    0.76000
# 345275   205072    333    0.81775
# 345276   205072    742    0.81775
# 345277   205072    412    0.80550
# 345278   205072    867    0.78700
# 345279   205072    469    0.78125
# 345300   205076    439    0.84750
# 345301   205076    603    0.74175
# 345302   205076    742    0.64700
# 345303   205076    388    0.64225
# 345304   205076    760    0.62725
# 345325   205383    742    0.82050
# 345326   205383    195    0.77075
# 345327   205383    999    0.73475
# 345328   205383    220    0.71575
# 345329   205383    323    0.70625
# 345350   205425    963    0.91825
# 345351   205425    742    0.91200
# 345352   205425    230    0.81975
# 345353   205425    504    0.78575
# 345354   205425   1071    0.76025
# 345375   206499    742    0.88600
# 345376   206499    777    0.80825
# 345377   206499    603    0.76725
# 345378   206499    855    0.75850
# 345379   206499    801    0.74475
#
#                                                       tag  user_tag  \
# 0                                                    toys      True
# 1                                      computer animation      True
# 2                                         pixar animation     False
# 3                                         kids and family      True
# 4                                               animation      True
# 25                                              adventure      True
# 26                                               children      True
# 27                                                fantasy      True
# 28                                                   kids      True
# 29                                        special effects     False
# 50                                                 sequel      True
# 51                                            good sequel     False
# 52                                                sequels     False
# 53                                                 comedy     False
# 54                                               original     False
# 75                                                  women     False
# 76                                            chick flick      True
# 77                                                divorce      True
# 78                                           girlie movie     False
# 79                                               romantic     False
# 100                                                sequel      True
# 101                                           good sequel     False
# 102                          father daughter relationship     False
# 103                                               sequels     False
# 104                                             pregnancy      True
# 125                                                 crime      True
# 126                                                 heist      True
# 127                                          bank robbery      True
# 128                                          great acting      True
# 129                                                action      True
# ...                                                   ...       ...
# 345250                                             family     False
# 345251                                        pornography     False
# 345252                                           original     False
# 345253                                             horror      True
# 345254                                            weapons      True
# 345275                                     dumb but funny     False
# 345276                                           original     False
# 345277                                         friendship     False
# 345278                                            runaway     False
# 345279                                        great movie     False
# 345300                                       girlie movie     False
# 345301                                              light     False
# 345302                                           original     False
# 345303                                          feel-good     False
# 345304  oscar (best writing - screenplay written direc...     False
# 345325                                           original     False
# 345326                                              chase     False
# 345327                                           suspense     False
# 345328                                             clever     False
# 345329                                              drama      True
# 345350                                    stand-up comedy      True
# 345351                                           original     False
# 345352                                             comedy      True
# 345353                                    highly quotable     False
# 345354                                         very funny     False
# 345375                                           original     False
# 345376                                              pg-13     False
# 345377                                              light     False
# 345378                                          road trip      True
# 345379                                        pornography     False
#
#                                                 ut_tstamp
# 0       {1494862083, 1246932614, 1449840522, 126653429...
# 1       {1274197762, 1494862082, 1514919558, 152011546...
# 2                                                     NaN
# 3                                            {1367943150}
# 4       {1470206081, 1329527940, 1147410824, 150497972...
# 25       {1368842814, 1560892764, 1555875358, 1446853492}
# 26                                           {1249829577}
# 27      {1154126755, 1328614307, 1325585318, 125038771...
# 28                                           {1446853547}
# 29                                                    NaN
# 50                               {1385355832, 1354556170}
# 51                                                    NaN
# 52                                                    NaN
# 53                                                    NaN
# 54                                                    NaN
# 75                                                    NaN
# 76                   {1528512704, 1308558977, 1362769982}
# 77                                           {1528512704}
# 78                                                    NaN
# 79                                                    NaN
# 100                                          {1137102574}
# 101                                                   NaN
# 102                                                   NaN
# 103                                                   NaN
# 104                              {1147409794, 1528513373}
# 125     {1571776011, 1528913425, 1427028503, 155253045...
# 126     {1562941313, 1552530466, 1527452905, 153221470...
# 127     {1410978177, 1567014434, 1549803845, 146611207...
# 128     {1495534976, 1571776008, 1540064393, 145902733...
# 129                                          {1399223692}
# ...                                                   ...
# 345250                                                NaN
# 345251                                                NaN
# 345252                                                NaN
# 345253                                       {1569693459}
# 345254                                       {1569693524}
# 345275                                                NaN
# 345276                                                NaN
# 345277                                                NaN
# 345278                                                NaN
# 345279                                                NaN
# 345300                                                NaN
# 345301                                                NaN
# 345302                                                NaN
# 345303                                                NaN
# 345304                                                NaN
# 345325                                                NaN
# 345326                                                NaN
# 345327                                                NaN
# 345328                                                NaN
# 345329                                       {1573140615}
# 345350               {1566845305, 1568298035, 1567544259}
# 345351                                                NaN
# 345352                           {1567139793, 1567544259}
# 345353                                                NaN
# 345354                                                NaN
# 345375                                                NaN
# 345376                                                NaN
# 345377                                                NaN
# 345378                                       {1569777591}
# 345379                                                NaN
#
# [69080 rows x 6 columns]

# %%
gs_gp2.mean().std()
# Out:
# tagId        74.115519
# relevance     0.105364
# user_tag      0.145055
# dtype: float64

# %%
gs_gp2.count()
print(gs_gp2.ut_tstamp.count().mean(),gs_gp2.ut_tstamp.count().std())
# Out:
# 5.057397220613781 4.852642056251426

# %%
gs_gp4 = gs_gp.apply(top_g2)
gs_gp4 = gs_gp4.reset_index(level = [0,1], drop = True)
gs_gp4 = gs_gp4.groupby(gs_gp4.movieId)
print(gs_gp4.ut_tstamp.count().mean(),gs_gp4.ut_tstamp.count().std())
# Out:
# 4.125796178343949 3.6262740718281576

# %%
gs_gp4 = gs_gp.apply(top_g2)
gs_gp4 = gs_gp4.reset_index(level = [0,1], drop = True)
gs_gp4.to_csv('tag_upd_25.csv')

# %%
#second improved and working verion of top g!
def top_g_50(x):
    
    try: 
        #first thing is to create the user tag, have to place in a try block because
        #some movies do not have user tags. So you are assigning a boolean series
        #based on whether users tagged movies with a scored tag
        y = x.assign(user_tag = x.tag.isin(gp_tags.get_group(x.movieId.iloc[0]).tag))
        
    except:
        #if you hit a key error, aka no tags, then simply assign a false boolean series
        y = x.assign(user_tag = [False]*len(x.index))
        
    #y = y.assign(ut_tstamp = [np.nan]*len(x.index))
    
    y['ut_tstamp'] = y.apply(lambda x : tag_tstamp2(x),axis = 1)
    
    y = y.sort_values(by = 'relevance', ascending = False).iloc[0:50]
    
    return y

gs_gp_50 = gs_gp.apply(top_g_50)
gs_gp_50 = gs_gp_50.reset_index(level = [0,1], drop = True)
gs_gp_50.to_csv('tag_upd_50.csv')
